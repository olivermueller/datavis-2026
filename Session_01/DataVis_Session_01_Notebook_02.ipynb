# %% [markdown]
# # Data Vis: Introduction
# * Notebook 2: Create Your Own Plot

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# # Data

# %% [markdown]
# Read CSV file into a DataFrame.

# %%
df = pd.read_csv("world_happiness_report.csv")

# %% [markdown]
# Rename columns for better readability.

# %%
df = df.drop(columns=["upperwhisker", "lowerwhisker", "Dystopia + residual"])

df = df.rename(columns={
    "Country name": "country",
    "Regional indicator": "region",
    "Ladder score": "happiness",
    "Log GDP per capita": "gdp_per_capita",
    "Social support": "social_support",
    "Healthy life expectancy": "life_expectancy",
    "Freedom to make life choices": "freedom",
    "Generosity": "generosity",
    "Perceptions of corruption": "corruption",
})

# %% [markdown]
# Show data.

# %%
df.head(20)
# Out:
#            country                        region  happiness  gdp_per_capita  \
# 0          Finland                Western Europe      7.741           1.844
# 1          Denmark                Western Europe      7.583           1.908
# 2          Iceland                Western Europe      7.525           1.881
# 3           Sweden                Western Europe      7.344           1.878
# 4           Israel  Middle East and North Africa      7.341           1.803
# 5      Netherlands                Western Europe      7.319           1.901
# 6           Norway                Western Europe      7.302           1.952
# 7       Luxembourg                Western Europe      7.122           2.141
# 8      Switzerland                Western Europe      7.060           1.970
# 9        Australia         North America and ANZ      7.057           1.854
# 10     New Zealand         North America and ANZ      7.029           1.810
# 11      Costa Rica   Latin America and Caribbean      6.955           1.561
# 12          Kuwait  Middle East and North Africa      6.951           1.845
# 13         Austria                Western Europe      6.905           1.885
# 14          Canada         North America and ANZ      6.900           1.840
# 15         Belgium                Western Europe      6.894           1.868
# 16         Ireland                Western Europe      6.838           2.129
# 17         Czechia    Central and Eastern Europe      6.822           1.783
# 18       Lithuania    Central and Eastern Europe      6.818           1.766
# 19  United Kingdom                Western Europe      6.749           1.822
#
#     social_support  life_expectancy  freedom  generosity  corruption
# 0            1.572            0.695    0.859       0.142       0.546
# 1            1.520            0.699    0.823       0.204       0.548
# 2            1.617            0.718    0.819       0.258       0.182
# 3            1.501            0.724    0.838       0.221       0.524
# 4            1.513            0.740    0.641       0.153       0.193
# 5            1.462            0.706    0.725       0.247       0.372
# 6            1.517            0.704    0.835       0.224       0.484
# 7            1.355            0.708    0.801       0.146       0.432
# 8            1.425            0.747    0.759       0.173       0.498
# 9            1.461            0.692    0.756       0.225       0.323
# 10           1.527            0.673    0.746       0.226       0.480
# 11           1.373            0.661    0.797       0.109       0.123
# 12           1.364            0.661    0.827       0.200       0.172
# 13           1.336            0.696    0.703       0.214       0.305
# 14           1.459            0.701    0.730       0.230       0.368
# 15           1.440            0.690    0.729       0.170       0.311
# 16           1.390            0.700    0.758       0.205       0.418
# 17           1.511            0.638    0.787       0.177       0.068
# 18           1.454            0.598    0.533       0.044       0.116
# 19           1.326            0.672    0.713       0.267       0.351

# %% [markdown]
# ## Plot

# %%
# YOUR TURN!
